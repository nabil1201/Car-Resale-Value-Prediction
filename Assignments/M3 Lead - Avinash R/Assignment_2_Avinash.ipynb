# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Dataset

# %%
data = pd.read_csv('Churn_Modelling.csv', index_col='RowNumber')
data
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
# ...              ...            ...        ...             ...
# 9996            0.00              2          1               0
# 9997        57369.61              1          1               1
# 9998            0.00              1          0               1
# 9999        75075.31              2          1               0
# 10000      130142.79              1          1               0
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0
# ...                    ...     ...
# 9996              96270.64       0
# 9997             101699.77       0
# 9998              42085.58       1
# 9999              92888.52       1
# 10000             38190.78       0
#
# [10000 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
data.drop('Surname', axis=1, inplace=True)

# %% [markdown]
# # Univariate Analysis

# %%
plt.hist(data['CreditScore']);
plt.xlabel('CreditScore');

# %%
plt.hist(data['Geography']);
plt.xlabel('Geography');

# %%
plt.hist(data['Gender']);
plt.xlabel('Gender');

# %%
plt.hist(data['Age']);
plt.xlabel('Age');

# %%
plt.hist(data['CreditScore']);
plt.xlabel('CreditScore');

# %%
plt.figure(figsize=(10, 4))
sns.boxplot(x=data['Balance']);
plt.xlabel('Balance');

# %%
plt.hist(data['NumOfProducts']);
plt.xlabel('Num of Products');

# %%
plt.hist(data['HasCrCard']);
plt.xlabel('Har Credit Card');

# %%
plt.hist(data['IsActiveMember']);
plt.xlabel('Is Active Member');

# %%
plt.figure(figsize=(10, 4))
sns.boxplot(x=data['EstimatedSalary']);
plt.xlabel('Estimated Salary');

# %%
plt.hist(data['Exited']);
plt.xlabel('Exited');

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x=data['CreditScore'], y=data['Age']);
plt.xlabel('Credit Score');
plt.ylabel('Age');

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['CreditScore'], data['Balance']);
plt.xlabel('Credit Score');
plt.ylabel('Balance');

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x=data['CreditScore'], y=data['EstimatedSalary']);
plt.xlabel('Credit Score');
plt.ylabel('Estimated Salary');

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=data["Age"], y=data["NumOfProducts"]);
plt.xlabel('Age');
plt.ylabel('Number of Products');

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(data[['CreditScore', 'Age', 'Gender', 'Tenure', 'Balance', 'EstimatedSalary']], hue='Age');

# %%
sns.pairplot(data[['CreditScore', 'Age', 'Gender', 'Tenure', 'Balance', 'EstimatedSalary']], hue='Gender');

# %%
plt.figure(figsize=(10, 6));
sns.heatmap(data.corr(), annot=True);

# %% [markdown]
# # Descriptive Statistics

# %%
data.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure        Balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# min         1.000000      0.00000        0.000000        11.580000
# 25%         1.000000      0.00000        0.000000     51002.110000
# 50%         1.000000      1.00000        1.000000    100193.915000
# 75%         2.000000      1.00000        1.000000    149388.247500
# max         4.000000      1.00000        1.000000    199992.480000
#
#              Exited
# count  10000.000000
# mean       0.203700
# std        0.402769
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# # Handle Missing Values

# %%
data.isna().sum()
# Out:
# CustomerId         0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # Outlier Handling

# %%
def Flooring_outlier(col):
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    whisker_width = 1.5
    lower_whisker = Q1 -(whisker_width*IQR)
    upper_whisker = Q3 + (whisker_width*IQR)
    data[col]=np.where(data[col]>upper_whisker,upper_whisker,np.where(data[col]<lower_whisker,lower_whisker,data[col]))

# %%
def remove_outlier(col):
    fig, axes = plt.subplots(1, 2, figsize=(20, 6))

    sns.boxplot(ax=axes[0], data=data, x=col)
    Flooring_outlier(col)
    sns.boxplot(ax=axes[1], data=data, x=col)

for col in ['CreditScore', 'Age', 'NumOfProducts']:
    remove_outlier(col)

# %%
data
# Out:
#            CustomerId  CreditScore Geography  Gender   Age  Tenure    Balance  \
# RowNumber
# 1            15634602        619.0    France  Female  42.0       2       0.00
# 2            15647311        608.0     Spain  Female  41.0       1   83807.86
# 3            15619304        502.0    France  Female  42.0       8  159660.80
# 4            15701354        699.0    France  Female  39.0       1       0.00
# 5            15737888        850.0     Spain  Female  43.0       2  125510.82
# ...               ...          ...       ...     ...   ...     ...        ...
# 9996         15606229        771.0    France    Male  39.0       5       0.00
# 9997         15569892        516.0    France    Male  35.0      10   57369.61
# 9998         15584532        709.0    France  Female  36.0       7       0.00
# 9999         15682355        772.0   Germany    Male  42.0       3   75075.31
# 10000        15628319        792.0    France  Female  28.0       4  130142.79
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# RowNumber
# 1                    1.0          1               1        101348.88       1
# 2                    1.0          0               1        112542.58       0
# 3                    3.0          1               0        113931.57       1
# 4                    2.0          0               0         93826.63       0
# 5                    1.0          1               1         79084.10       0
# ...                  ...        ...             ...              ...     ...
# 9996                 2.0          1               0         96270.64       0
# 9997                 1.0          1               1        101699.77       0
# 9998                 1.0          0               1         42085.58       1
# 9999                 2.0          1               0         92888.52       1
# 10000                1.0          1               0         38190.78       0
#
# [10000 rows x 12 columns]

# %% [markdown]
# # Encoding of Categorical Columns

# %%
data.columns
# Out:
# Index(['CustomerId', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
data = pd.get_dummies(data, columns = ['Geography', 'Gender'])

# %%
data.columns
# Out:
# Index(['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited', 'Geography_France', 'Geography_Germany', 'Geography_Spain',
#        'Gender_Female', 'Gender_Male'],
#       dtype='object')

# %% [markdown]
# # Split data into dependent and independent data

# %%
Y = data[['Exited']]
X = data.drop('Exited', axis=1)

# %%
X
# Out:
#            CustomerId  CreditScore   Age  Tenure    Balance  NumOfProducts  \
# RowNumber
# 1            15634602        619.0  42.0       2       0.00            1.0
# 2            15647311        608.0  41.0       1   83807.86            1.0
# 3            15619304        502.0  42.0       8  159660.80            3.0
# 4            15701354        699.0  39.0       1       0.00            2.0
# 5            15737888        850.0  43.0       2  125510.82            1.0
# ...               ...          ...   ...     ...        ...            ...
# 9996         15606229        771.0  39.0       5       0.00            2.0
# 9997         15569892        516.0  35.0      10   57369.61            1.0
# 9998         15584532        709.0  36.0       7       0.00            1.0
# 9999         15682355        772.0  42.0       3   75075.31            2.0
# 10000        15628319        792.0  28.0       4  130142.79            1.0
#
#            HasCrCard  IsActiveMember  EstimatedSalary  Geography_France  \
# RowNumber
# 1                  1               1        101348.88                 1
# 2                  0               1        112542.58                 0
# 3                  1               0        113931.57                 1
# 4                  0               0         93826.63                 1
# 5                  1               1         79084.10                 0
# ...              ...             ...              ...               ...
# 9996               1               0         96270.64                 1
# 9997               1               1        101699.77                 1
# 9998               0               1         42085.58                 1
# 9999               1               0         92888.52                 0
# 10000              1               0         38190.78                 1
#
#            Geography_Germany  Geography_Spain  Gender_Female  Gender_Male
# RowNumber
# 1                          0                0              1            0
# 2                          0                1              1            0
# 3                          0                0              1            0
# 4                          0                0              1            0
# 5                          0                1              1            0
# ...                      ...              ...            ...          ...
# 9996                       0                0              0            1
# 9997                       0                0              0            1
# 9998                       0                0              1            0
# 9999                       1                0              0            1
# 10000                      0                0              1            0
#
# [10000 rows x 14 columns]

# %%
Y
# Out:
#            Exited
# RowNumber
# 1               1
# 2               0
# 3               1
# 4               0
# 5               0
# ...           ...
# 9996            0
# 9997            0
# 9998            1
# 9999            1
# 10000           0
#
# [10000 rows x 1 columns]

# %% [markdown]
# # Scale the independent Column

# %%
sc=StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[-0.78321342, -0.32687761,  0.34261499, ..., -0.57380915,
#          1.09598752, -1.09598752],
#        [-0.60653412, -0.44080365,  0.24001108, ...,  1.74273971,
#          1.09598752, -1.09598752],
#        [-0.99588476, -1.53863634,  0.34261499, ..., -0.57380915,
#          1.09598752, -1.09598752],
#        ...,
#        [-1.47928179,  0.60524449, -0.27300849, ..., -0.57380915,
#          1.09598752, -1.09598752],
#        [-0.11935577,  1.25772996,  0.34261499, ..., -0.57380915,
#         -0.91241915,  0.91241915],
#        [-0.87055909,  1.4648682 , -1.09383981, ..., -0.57380915,
#          1.09598752, -1.09598752]])

# %% [markdown]
# # Split the data into training and testing

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((7000, 14), (3000, 14), (7000, 1), (3000, 1))
